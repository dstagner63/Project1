# %%
#Dependencies:
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
import operator

# %%
# Load in file
olympic_data = "olympic_data.csv"

# %%
# Read and display the CSV with Pandas
olympic_data_df = pd.read_csv(olympic_data, encoding = "ISO-8859-1")
olympic_data_df.head(20)
# Out:
#    Gender       Event     Location  Year Medal                Name  \
# 0       M  10000M Men    Stockholm  1912     G  Hannes KOLEHMAINEN
# 1       M  10000M Men    Stockholm  1912     S      Lewis TEWANIMA
# 2       M  10000M Men    Stockholm  1912     B      Albin STENROOS
# 3       M  10000M Men      Antwerp  1920     G         Paavo NURMI
# 4       M  10000M Men      Antwerp  1920     S    Joseph GUILLEMOT
# 5       M  10000M Men      Antwerp  1920     B        James WILSON
# 6       M  10000M Men        Paris  1924     G        Ville RITOLA
# 7       M  10000M Men        Paris  1924     S          Edvin WIDE
# 8       M  10000M Men        Paris  1924     B           Eero BERG
# 9       M  10000M Men    Amsterdam  1928     G         Paavo NURMI
# 10      M  10000M Men    Amsterdam  1928     S        Ville RITOLA
# 11      M  10000M Men    Amsterdam  1928     B          Edvin WIDE
# 12      M  10000M Men  Los Angeles  1932     G   Janusz KUSOCINSKI
# 13      M  10000M Men  Los Angeles  1932     S   Volmari ISO-HOLLO
# 14      M  10000M Men  Los Angeles  1932     B      Lauri VIRTANEN
# 15      M  10000M Men       Berlin  1936     G     Ilmari SALMINEN
# 16      M  10000M Men       Berlin  1936     S         Arvo ASKOLA
# 17      M  10000M Men       Berlin  1936     B   Volmari ISO-HOLLO
# 18      M  10000M Men       London  1948     G     Emil ZÃÂTOPEK
# 19      M  10000M Men       London  1948     S        Alain MIMOUN
#
#    Nationality   Result
# 0          FIN  31:20.8
# 1          USA  32:06.6
# 2          FIN  32:21.8
# 3          FIN  31:45.8
# 4          FRA  31:47.2
# 5          GBR  31:50.8
# 6          FIN  30:23.2
# 7          SWE  30:55.2
# 8          FIN  31:43.0
# 9          FIN  30:18.8
# 10         FIN  30:19.4
# 11         SWE  31:00.8
# 12         POL  30:11.4
# 13         FIN  30:12.6
# 14         FIN  30:35.0
# 15         FIN  30:15.4
# 16         FIN  30:15.6
# 17         FIN  30:20.2
# 18         TCH  29:59.6
# 19         FRA  30:47.4

# %%
# Create individual dataframes for each events
m_highjump_df = olympic_data_df.loc[olympic_data_df["Event"] == "High Jump Men"]
w_highjump_df = olympic_data_df.loc[olympic_data_df["Event"] == "High Jump Women"]
m_discus_df = olympic_data_df.loc[olympic_data_df["Event"] == "Discus Throw Men"]
w_discus_df = olympic_data_df.loc[olympic_data_df["Event"] == "Discus Throw Women"]
m_100_df = olympic_data_df.loc[olympic_data_df["Event"] == "100M Men"]
w_100_df = olympic_data_df.loc[olympic_data_df["Event"] == "100M Women"]
m_10000_df = olympic_data_df.loc[olympic_data_df["Event"] == "10000M Men"]
w_10000_df = olympic_data_df.loc[olympic_data_df["Event"] == "10000M Women"]
m_800_df = olympic_data_df.loc[olympic_data_df["Event"] == "800M Men"]
w_800_df = olympic_data_df.loc[olympic_data_df["Event"] == "800M Women"]

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
m_highjump_df["Result"] = m_highjump_df["Result"].map(lambda x:float(x))
m_highjump_gb = m_highjump_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
m_highjump_plt_df = pd.DataFrame(m_highjump_gb).reset_index()
mhj_gold_df = m_highjump_plt_df.loc[m_highjump_plt_df["Medal"]=="G",["Year", "Result"]]
mhj_silver_df = m_highjump_plt_df.loc[m_highjump_plt_df["Medal"]=="S",["Year", "Result"]]
mhj_bronze_df = m_highjump_plt_df.loc[m_highjump_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-5-0309ee60dd29>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_highjump_df["Result"] = m_highjump_df["Result"].map(lambda x:float(x))

# %%
# Plot the results for Womens High Jump
#Change result value into numberic value using lambda and then group by year
w_highjump_df["Result"] = w_highjump_df["Result"].map(lambda x:float(x))
w_highjump_gb = w_highjump_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
w_highjump_plt_df = pd.DataFrame(w_highjump_gb).reset_index()
whj_gold_df = w_highjump_plt_df.loc[w_highjump_plt_df["Medal"]=="G",["Year", "Result"]]
whj_silver_df = w_highjump_plt_df.loc[w_highjump_plt_df["Medal"]=="S",["Year", "Result"]]
whj_bronze_df = w_highjump_plt_df.loc[w_highjump_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-6-0a962bd7c0ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_highjump_df["Result"] = w_highjump_df["Result"].map(lambda x:float(x))

# %%
#Plot the three medal reults to line graph and save file to output folder
fig= plt.figure(figsize=(15,10))
plt.plot(mhj_gold_df["Year"], mhj_gold_df["Result"], linewidth=1, marker="o", color="gold", label="Gold")
plt.plot(mhj_silver_df["Year"], mhj_silver_df["Result"], linewidth=1, marker="o", color="silver", label="Silver")
plt.plot(mhj_bronze_df["Year"], mhj_bronze_df["Result"], linewidth=1, marker="o", color="orange", label="Bronze")
plt.plot(whj_gold_df["Year"], whj_gold_df["Result"], linewidth=1, marker="+", color="green", label="Gold")
plt.plot(whj_silver_df["Year"], whj_silver_df["Result"], linewidth=1, marker="+", color="red", label="Silver")
plt.plot(whj_bronze_df["Year"], whj_bronze_df["Result"], linewidth=1, marker="+", color="blue", label="Bronze")


plt.grid()
plt.legend(loc="lower right")
plt.title("Men and Women's High Jump Medal Results 1896-2016")
plt.xlabel("Olympic Year")
plt.ylabel("Event Result")
plt.savefig("Output/Men and Women's High Jump Medal Results 1896-2016.png")
plt.show()

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
m_discus_df["Result"] = m_discus_df["Result"].map(lambda x:float(x))
m_discus_gb = m_discus_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
m_discus_plt_df = pd.DataFrame(m_discus_gb).reset_index()
md_gold_df = m_discus_plt_df.loc[m_discus_plt_df["Medal"]=="G",["Year", "Result"]]
md_silver_df = m_discus_plt_df.loc[m_discus_plt_df["Medal"]=="S",["Year", "Result"]]
md_bronze_df = m_discus_plt_df.loc[m_discus_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-8-3479b5332ed6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_discus_df["Result"] = m_discus_df["Result"].map(lambda x:float(x))

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
w_discus_df["Result"] = w_discus_df["Result"].map(lambda x:float(x))
w_discus_gb = w_discus_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
w_discus_plt_df = pd.DataFrame(w_discus_gb).reset_index()
wd_gold_df = w_discus_plt_df.loc[w_discus_plt_df["Medal"]=="G",["Year", "Result"]]
wd_silver_df = w_discus_plt_df.loc[w_discus_plt_df["Medal"]=="S",["Year", "Result"]]
wd_bronze_df = w_discus_plt_df.loc[w_discus_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-9-a15f9697544c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_discus_df["Result"] = w_discus_df["Result"].map(lambda x:float(x))

# %%
#Plot the three medal reults to line graph and save file to output folder
fig= plt.figure(figsize=(15,10))
plt.plot(md_gold_df["Year"], md_gold_df["Result"], linewidth=1, marker="o", color="gold", label="Gold")
plt.plot(md_silver_df["Year"], md_silver_df["Result"], linewidth=1, marker="o", color="silver", label="Silver")
plt.plot(md_bronze_df["Year"], md_bronze_df["Result"], linewidth=1, marker="o", color="orange", label="Bronze")
plt.plot(wd_gold_df["Year"], wd_gold_df["Result"], linewidth=1, marker="+", color="green", label="Gold")
plt.plot(wd_silver_df["Year"], wd_silver_df["Result"], linewidth=1, marker="+", color="red", label="Silver")
plt.plot(wd_bronze_df["Year"], wd_bronze_df["Result"], linewidth=1, marker="+", color="blue", label="Bronze")


plt.grid()
plt.legend(loc="lower right")
plt.title("Men and Women's Discus Medal Results 1896-2016")
plt.xlabel("Olympic Year")
plt.ylabel("Event Result")
plt.savefig("Output/Men and Women's Discus Medal Results 1896-2016.png")
plt.show()

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
m_100_df["Result"] = m_100_df["Result"].map(lambda x:float(x))
m_100_gb = m_100_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
m_100_plt_df = pd.DataFrame(m_100_gb).reset_index()
m100_gold_df = m_100_plt_df.loc[m_100_plt_df["Medal"]=="G",["Year", "Result"]]
m100_silver_df = m_100_plt_df.loc[m_100_plt_df["Medal"]=="S",["Year", "Result"]]
m100_bronze_df = m_100_plt_df.loc[m_100_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-11-5adb0603820f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_100_df["Result"] = m_100_df["Result"].map(lambda x:float(x))

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
w_100_df["Result"] = w_100_df["Result"].map(lambda x:float(x))
w_100_gb = w_100_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
w_100_plt_df = pd.DataFrame(w_100_gb).reset_index()
w100_gold_df = w_100_plt_df.loc[w_100_plt_df["Medal"]=="G",["Year", "Result"]]
w100_silver_df = w_100_plt_df.loc[w_100_plt_df["Medal"]=="S",["Year", "Result"]]
w100_bronze_df = w_100_plt_df.loc[w_100_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# <ipython-input-12-5af05c6ee539>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_100_df["Result"] = w_100_df["Result"].map(lambda x:float(x))

# %%
#Plot the three medal reults to line graph and save file to output folder
fig= plt.figure(figsize=(15,10))
plt.plot(m100_gold_df["Year"], m100_gold_df["Result"], linewidth=1, marker="o", color="gold", label="Gold")
plt.plot(m100_silver_df["Year"], m100_silver_df["Result"], linewidth=1, marker="o", color="silver", label="Silver")
plt.plot(m100_bronze_df["Year"], m100_bronze_df["Result"], linewidth=1, marker="o", color="orange", label="Bronze")
plt.plot(w100_gold_df["Year"], w100_gold_df["Result"], linewidth=1, marker="+", color="green", label="Gold")
plt.plot(w100_silver_df["Year"], w100_silver_df["Result"], linewidth=1, marker="+", color="red", label="Silver")
plt.plot(w100_bronze_df["Year"], w100_bronze_df["Result"], linewidth=1, marker="+", color="blue", label="Bronze")


plt.grid()
plt.legend(loc="upper right")
plt.title("Men and Women's 100M Medal Results 1896-2016")
plt.xlabel("Olympic Year")
plt.ylabel("Event Result")
plt.savefig("Output/Men and Women's 100M Medal Results 1896-2016.png")
plt.show()

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
m_800_df["Result"] = m_800_df["Result"].map(lambda x:float(x))
m_800_gb = m_800_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
m_800_plt_df = pd.DataFrame(m_800_gb).reset_index()
m800_gold_df = m_800_plt_df.loc[m_800_plt_df["Medal"]=="G",["Year", "Result"]]
m800_silver_df = m_800_plt_df.loc[m_800_plt_df["Medal"]=="S",["Year", "Result"]]
m800_bronze_df = m_800_plt_df.loc[m_800_plt_df["Medal"]=="B",["Year", "Result"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6d76c1c3246e> in <module>
#       1 # Plot the results for Mens High Jump
#       2 #Change result value into numberic value using lambda and then group by year
# ----> 3 m_800_df["Result"] = m_800_df["Result"].map(lambda x:float(x))
#       4 m_800_gb = m_800_df.groupby(['Year',"Medal"])["Result"].mean()
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-14-6d76c1c3246e> in <lambda>(x)
#       1 # Plot the results for Mens High Jump
#       2 #Change result value into numberic value using lambda and then group by year
# ----> 3 m_800_df["Result"] = m_800_df["Result"].map(lambda x:float(x))
#       4 m_800_gb = m_800_df.groupby(['Year',"Medal"])["Result"].mean()
#       5
#
# ValueError: could not convert string to float: '02:11.0'

# %%
# Plot the results for Mens High Jump
#Change result value into numberic value using lambda and then group by year
w_800_df["Result"] = w_800_df["Result"].map(lambda x:float(x))
w_800_gb = w_800_df.groupby(['Year',"Medal"])["Result"].mean()

#Create dataframe to plot and reset index then create dataframes for each medal
w_800_plt_df = pd.DataFrame(w_800_gb).reset_index()
w800_gold_df = w_800_plt_df.loc[w_800_plt_df["Medal"]=="G",["Year", "Result"]]
w800_silver_df = w_800_plt_df.loc[w_800_plt_df["Medal"]=="S",["Year", "Result"]]
w800_bronze_df = w_800_plt_df.loc[w_800_plt_df["Medal"]=="B",["Year", "Result"]]

# %%
#Plot the three medal reults to line graph and save file to output folder
fig= plt.figure(figsize=(15,10))
plt.plot(m800_gold_df["Year"], m800_gold_df["Result"], linewidth=1, marker="+", color="gold", label="Gold")
plt.plot(m800_silver_df["Year"], m800_silver_df["Result"], linewidth=1, marker="+", color="silver", label="Silver")
plt.plot(m800_bronze_df["Year"], m800_bronze_df["Result"], linewidth=1, marker="+", color="orange", label="Bronze")
plt.plot(w800_gold_df["Year"], w800_gold_df["Result"], linewidth=1, marker="+", color="gold", label="Gold")
plt.plot(w800_silver_df["Year"], w800_silver_df["Result"], linewidth=1, marker="+", color="silver", label="Silver")
plt.plot(w800_bronze_df["Year"], w800_bronze_df["Result"], linewidth=1, marker="+", color="orange", label="Bronze")


plt.grid()
plt.legend(loc="lower right")
plt.title("Men and Women's 800M Medal Results 1896-2016")
plt.xlabel("Olympic Year")
plt.ylabel("Event Result")
plt.savefig("Output/Men and Women's 800M Medal Results 1896-2016.png")
plt.show()
